# %%
from keras.datasets import mnist
data=mnist.load_data()
((x_train, y_train),(x_test, y_test))=data
x_train=x_train.reshape((x_train.shape[0],28*28)).astype('float32')
x_test=x_test.reshape((x_test.shape[0],28*28)).astype('float32')
x_train=x_train/255
x_test=x_test/255
from keras.utils import np_utils
y_train=np_utils.to_categorical(y_train)
y_test=np_utils.to_categorical(y_test)
num_classes=y_test.shape[1]
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(32,input_dim=28*28,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])
model.summary()
model.fit(x_train,y_train,epochs=10,batch_size=100)
scores=model.evaluate(x_test,y_test)
print(scores)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.7619 - accuracy: 0.7777
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2186 - accuracy: 0.9358
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1679 - accuracy: 0.9507
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1391 - accuracy: 0.9580
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1183 - accuracy: 0.9653
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1066 - accuracy: 0.9681
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0921 - accuracy: 0.9714
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0850 - accuracy: 0.9738
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0773 - accuracy: 0.9760
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0661 - accuracy: 0.9794
# 313/313 [==============================] - 0s 880us/step - loss: 0.1046 - accuracy: 0.9690
# [0.10462242364883423, 0.968999981880188]
